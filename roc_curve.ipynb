# %% [markdown]
# <a href="https://colab.research.google.com/github/rgbdirik/rgbdirik/blob/python_programming/roc_curve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Gerçek Pozitif Oranları (TPR) ve Yanlış Pozitif Oranları (FPR)
tpr = [0.9, 0.85, 0.78, 0.66, 0.55]
fpr = [0.05, 0.10, 0.15, 0.20, 0.25]

# ROC eğrisini çizme
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC Curve')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guess')

plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# AUC hesaplama
roc_auc = auc(fpr, tpr)
print("AUC (Area Under the Curve):", roc_auc)

# Eğriyi gösterme
plt.show()
# Out:
# AUC (Area Under the Curve): 0.15075

# %%
import matplotlib.pyplot as plt

# TPR değerleri
tpr = [0.9, 0.85, 0.78, 0.66, 0.55]

# FPR değerleri
fpr = [0.05, 0.10, 0.15, 0.20, 0.25]

# ROC eğrisini çizme
plt.plot(fpr, tpr)
plt.xlabel("Yanlış Pozitif Oranı (FPR)")
plt.ylabel("Gerçek Pozitif Oranı (TPR)")
plt.show()
